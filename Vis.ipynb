# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import sklearn as skl

# %%
orgDF=pd.read_csv("heart.csv")

DF=pd.read_csv("heart_clean.csv")
clDF=DF.drop(['HeartDisease_0', "Sex_M", "ExerciseAngina_N"], axis =1)
clDF.info()

numDF=clDF[["Age","RestingBP","Cholesterol","Oldpeak", "MaxHR","Sex_F"]]
catDF=clDF[["Sex_F", "ChestPainType_ASY", "ChestPainType_ATA","ChestPainType_NAP","ChestPainType_TA","RestingECG_Normal","RestingECG_ST","ExerciseAngina_Y", "ST_Slope_Down","ST_Slope_Flat","ST_Slope_Up", "HeartDisease_1"]]
numDF.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917 entries, 0 to 916
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                917 non-null    float64
#  1   RestingBP          917 non-null    float64
#  2   Cholesterol        917 non-null    float64
#  3   FastingBS          917 non-null    float64
#  4   MaxHR              917 non-null    float64
#  5   Oldpeak            917 non-null    float64
#  6   Sex_F              917 non-null    float64
#  7   ChestPainType_ASY  917 non-null    float64
#  8   ChestPainType_ATA  917 non-null    float64
#  9   ChestPainType_NAP  917 non-null    float64
#  10  ChestPainType_TA   917 non-null    float64
#  11  RestingECG_LVH     917 non-null    float64
#  12  RestingECG_Normal  917 non-null    float64
#  13  RestingECG_ST      917 non-null    float64
#  14  ExerciseAngina_Y   917 non-null    float64
#  15  ST_Slope_Down      917 non-null    float64
#  16  ST_Slope_Flat      917 non-null    float64
#  17  ST_Slope_Up        917 non-null    float64
#  18  HeartDisease_1     917 non-null    float64
# dtypes: float64(19)
# memory usage: 136.2 KB
#     Age  RestingBP  Cholesterol  Oldpeak  MaxHR
# 0  40.0      140.0        289.0      0.0  172.0
# 1  49.0      160.0        180.0      1.0  156.0
# 2  37.0      130.0        283.0      0.0   98.0
# 3  48.0      138.0        214.0      1.5  108.0
# 4  54.0      150.0        195.0      0.0  122.0

# %% [markdown]
# Numerical Features: Age, ResingBP, Cholesterol, MaxHR, Oldpeak
#
# Age:

# %%
ax=sns.histplot(clDF,x="Age", kde=True, color="Red")
ax.set_xlabel("Age")
ax.set_ylabel("Count")
ax.set_title("Age Distribution of Data")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Data')

# %%
ax=sns.boxplot(data=clDF,x=clDF["Age"], width=.99, color="pink")

# %% [markdown]
# Resting Blood Pressure:

# %%
ax=sns.histplot(clDF,x="RestingBP", kde=True, color="Red")
ax.set_xlabel("RestingBP")
ax.set_ylabel("Count")
ax.set_title("RestingBP Distribution of Data")
# Out:
# Text(0.5, 1.0, 'RestingBP Distribution of Data')

# %%
ax=sns.boxplot(data=clDF,x=clDF["RestingBP"], width=.99, color="pink")

# %% [markdown]
# Cholesterol:

# %%
ax=sns.histplot(clDF,x="Cholesterol", kde=True, color="Red")
ax.set_xlabel("Cholesterol")
ax.set_ylabel("Count")
ax.set_title("Cholesterol Distribution of Data")
# Out:
# Text(0.5, 1.0, 'Cholesterol Distribution of Data')

# %%
ax=sns.boxplot(data=clDF,x=clDF["Cholesterol"], width=.99, color="pink")

# %% [markdown]
# Max Heart Rate:

# %%
ax=sns.histplot(clDF,x="MaxHR", kde=True, color="Red")
ax.set_xlabel("MaxHR")
ax.set_ylabel("Count")
ax.set_title("MaxHR Distribution of Data")
# Out:
# Text(0.5, 1.0, 'MaxHR Distribution of Data')

# %%
ax=sns.boxplot(data=clDF,x=clDF["MaxHR"], width=.99, color="pink")

# %% [markdown]
# Oldpeak:

# %%
ax=sns.histplot(clDF,x="Oldpeak", kde=True, color="Red")
ax.set_xlabel("Oldpeak")
ax.set_ylabel("Count")
ax.set_title("Oldpeak Distribution of Data")
# Out:
# Text(0.5, 1.0, 'Oldpeak Distribution of Data')

# %%
ax=sns.boxplot(data=clDF,x=clDF["Oldpeak"], width=.99, color="pink")

# %% [markdown]
# Categorical Features:
# Sex, ChestPainType_ASY, ChestPainType_ATA, ChestPainType_NAP, ChestPainType_TA

# %%
plt.figure()
sns.countplot(data=clDF, x="Sex_F", hue="HeartDisease_1")
plt.title("Heart Disease by Sex")
plt.xlabel("Male/Female")
plt.legend(labels=["Does Not Have Heart Disease", "Has Heart Disease"])

# %% [markdown]
# Chest Pain Type:

# %%
plot=sns.FacetGrid(orgDF, col="HeartDisease")
plot.map(sns.histplot, "ChestPainType", color="pink")

# %% [markdown]
# Comparision of Numerical Features

# %%
sns.pairplot(, hue ='Sex-F', palette={"0":"blue","1":"pink"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex-F'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sns.pairplot(orgDF, hue ='Sex-F', palette={"0":"blue","1":"pink"})
#
# File c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:2119, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117 # Set up the PairGrid
#    2118 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                 hue_order=hue_order, palette=palette, corner=corner,
#    2121                 height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2123 # Add the markers here as PairGrid has figured out how many levels of the
#    2124 # hue variable are needed and we don't want to duplicate that process
#    2125 if markers is not None:
#
# File c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:1327, in PairGrid.__init__(self, data, hue, vars, x_vars, y_vars, hue_order, palette, hue_kws, corner, diag_sharey, height, aspect, layout_pad, despine, dropna)
#    1316     self.hue_vals = pd.Series(["_nolegend_"] * len(data),
#    1317                               index=data.index)
#    1318 else:
#    1319     # We need hue_order and hue_names because the former is used to control
#    1320     # the order of drawing and the latter is used to control the order of
#    (...)
#    1325     # to the axes-level functions, while always handling legend creation.
#    1326     # See GH2307
# -> 1327     hue_names = hue_order = categorical_order(data[hue], hue_order)
#    1328     if dropna:
#    1329         # Filter NA from the list of unique hue names
#    1330         hue_names = list(filter(pd.notnull, hue_names))
#
# File c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Sex-F'
